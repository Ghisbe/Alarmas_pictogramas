# %% [markdown]
# <a href="https://colab.research.google.com/github/Ghisbe/Alarmas_pictogramas/blob/main/Segunda_limpieza.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
import zipfile
import pandas as pd
# Out:
# Mounted at /content/drive

# %%
import gdown

# %%
# URL de compartido del archivo CSV en Google Drive

# URL de descarga directa del archivo CSV en Google Drive
url = "https://drive.google.com/uc?id=1EoEqJHbGgVSDRIg5Fv_m_OCGoBJOLFkp"

# %%
# Descargar el archivo CSV
output = 'alertas_clima.csv'
gdown.download(url, output, quiet=False)

# Leer el archivo CSV en un DataFrame de pandas
df = pd.read_csv(output)

# Mostrar el DataFrame
print(df)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1EoEqJHbGgVSDRIg5Fv_m_OCGoBJOLFkp
# From (redirected): https://drive.google.com/uc?id=1EoEqJHbGgVSDRIg5Fv_m_OCGoBJOLFkp&confirm=t&uuid=42dc4a20-ebee-4634-acbe-57a4d7b4c0d2
# To: /content/alertas_clima.csv
# 100%|██████████| 2.13G/2.13G [00:27<00:00, 77.7MB/s]
#                                id                      event  \
# 0        5ed3a4b2283336e2e7db3a1c  Special Weather Statement
# 1        5ed3a07c283336e2e7d2bfa4              Flood Warning
# 2        5ed39e54283336e2e7d22306             Flood Advisory
# 3        5ed39e11283336e2e7d15e23                Flood Watch
# 4        5ed3962c283336e2e7c1d935              Flood Warning
# ...                           ...                        ...
# 2267347  613a65bc434e34d5ee196c5e              Flood Warning
# 2267348  613a681c434e34d5ee1acbf5              Flood Warning
# 2267349  613a681c434e34d5ee1acc1a              Flood Warning
# ...

# %%
df
# Out:
#                                id                      event  \
# 0        5ed3a4b2283336e2e7db3a1c  Special Weather Statement
# 1        5ed3a07c283336e2e7d2bfa4              Flood Warning
# 2        5ed39e54283336e2e7d22306             Flood Advisory
# 3        5ed39e11283336e2e7d15e23                Flood Watch
# 4        5ed3962c283336e2e7c1d935              Flood Warning
# ...                           ...                        ...
# 2267347  613a65bc434e34d5ee196c5e              Flood Warning
# 2267348  613a681c434e34d5ee1acbf5              Flood Warning
# 2267349  613a681c434e34d5ee1acc1a              Flood Warning
# 2267350  613a6888434e34d5ee1f23ac              Flood Warning
# 2267351  613a6888434e34d5ee1f23db              Flood Warning
#
#                                                description  \
# 0        At 630 AM MDT/530 AM PDT/, Doppler radar was t...
# 1        ...The National Weather Service in Billings MT...
# ...

# %%
# cantidad de valores nulos en cada columna
nulos_por_columna = df.isnull().sum()

# cantidad de valores nulos en todo el DataFrame
total_nulos = df.isnull().sum().sum()

print("Valores nulos por columna:")
print(nulos_por_columna)
print("\nTotal de valores nulos en el DataFrame:", total_nulos)
# Out:
# Valores nulos por columna:
# id                  0
# event               0
# description      3380
# instruction    486951
# urgency             0
# severity            0
# dtype: int64
#
# Total de valores nulos en el DataFrame: 490331

# %%
# elimina registros con valores nulos en todo el DataFrame
df_sin_nulos = df.dropna(subset=['description', 'instruction'])

# %%
df_sin_nulos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1778590 entries, 0 to 2267337
# Data columns (total 6 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   id           object
#  1   event        object
#  2   description  object
#  3   instruction  object
#  4   urgency      object
#  5   severity     object
# dtypes: object(6)
# memory usage: 95.0+ MB

# %%
df_sin_nulos
# Out:
#                                id                      event  \
# 0        5ed3a4b2283336e2e7db3a1c  Special Weather Statement
# 1        5ed3a07c283336e2e7d2bfa4              Flood Warning
# 2        5ed39e54283336e2e7d22306             Flood Advisory
# 3        5ed39e11283336e2e7d15e23                Flood Watch
# 4        5ed3962c283336e2e7c1d935              Flood Warning
# ...                           ...                        ...
# 2267325  613a5aee434e34d5ee03f0e1  Special Weather Statement
# 2267326  613a5c5b434e34d5ee06813a  Special Weather Statement
# 2267327  613a5c5b434e34d5ee06813f          Flash Flood Watch
# 2267333  613a5d4d434e34d5ee06a9a9         Dense Fog Advisory
# 2267337  613a5dc6434e34d5ee06bd10  Special Weather Statement
#
#                                                description  \
# 0        At 630 AM MDT/530 AM PDT/, Doppler radar was t...
# 1        ...The National Weather Service in Billings MT...
# ...

# %%
# cantidad de registros con instrucción  \n\n
filas_nn = df_sin_nulos[df_sin_nulos['instruction'] == '\n\n']
cantidad_nn = len(filas_nn)
cantidad_nn
# Out:
# 281314

# %%
# elimina registros con valores \n\n en el campo instrucción
df_filtrado = df_sin_nulos[df_sin_nulos['instruction'] != '\n\n']

# %%
df_filtrado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1497276 entries, 0 to 2267337
# Data columns (total 6 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   id           1497276 non-null  object
#  1   event        1497276 non-null  object
#  2   description  1497276 non-null  object
#  3   instruction  1497276 non-null  object
#  4   urgency      1497276 non-null  object
#  5   severity     1497276 non-null  object
# dtypes: object(6)
# memory usage: 80.0+ MB

# %%
df_filtrado
# Out:
#                                id                      event  \
# 0        5ed3a4b2283336e2e7db3a1c  Special Weather Statement
# 1        5ed3a07c283336e2e7d2bfa4              Flood Warning
# 2        5ed39e54283336e2e7d22306             Flood Advisory
# 3        5ed39e11283336e2e7d15e23                Flood Watch
# 4        5ed3962c283336e2e7c1d935              Flood Warning
# ...                           ...                        ...
# 2267325  613a5aee434e34d5ee03f0e1  Special Weather Statement
# 2267326  613a5c5b434e34d5ee06813a  Special Weather Statement
# 2267327  613a5c5b434e34d5ee06813f          Flash Flood Watch
# 2267333  613a5d4d434e34d5ee06a9a9         Dense Fog Advisory
# 2267337  613a5dc6434e34d5ee06bd10  Special Weather Statement
#
#                                                description  \
# 0        At 630 AM MDT/530 AM PDT/, Doppler radar was t...
# 1        ...The National Weather Service in Billings MT...
# ...

# %%
#revisión de valores únicos
valores_unicos_urgency = df_filtrado['urgency'].unique()
valores_unicos_urgency
# Out:
# array(['Expected', 'Future', 'Past', 'Immediate', 'Unknown'], dtype=object)

# %%
# Elimina los registros donde el campo 'urgency' tiene el valor 'Unknown'
df_filtrado_sin_unknown = df_filtrado.loc[df_filtrado['urgency'] != 'Unknown']

# %%
df_filtrado_sin_unknown.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1497260 entries, 0 to 2267337
# Data columns (total 6 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   id           1497260 non-null  object
#  1   event        1497260 non-null  object
#  2   description  1497260 non-null  object
#  3   instruction  1497260 non-null  object
#  4   urgency      1497260 non-null  object
#  5   severity     1497260 non-null  object
# dtypes: object(6)
# memory usage: 80.0+ MB

# %%
df_filtrado_sin_unknown
# Out:
#                                id                      event  \
# 0        5ed3a4b2283336e2e7db3a1c  Special Weather Statement
# 1        5ed3a07c283336e2e7d2bfa4              Flood Warning
# 2        5ed39e54283336e2e7d22306             Flood Advisory
# 3        5ed39e11283336e2e7d15e23                Flood Watch
# 4        5ed3962c283336e2e7c1d935              Flood Warning
# ...                           ...                        ...
# 2267325  613a5aee434e34d5ee03f0e1  Special Weather Statement
# 2267326  613a5c5b434e34d5ee06813a  Special Weather Statement
# 2267327  613a5c5b434e34d5ee06813f          Flash Flood Watch
# 2267333  613a5d4d434e34d5ee06a9a9         Dense Fog Advisory
# 2267337  613a5dc6434e34d5ee06bd10  Special Weather Statement
#
#                                                description  \
# 0        At 630 AM MDT/530 AM PDT/, Doppler radar was t...
# 1        ...The National Weather Service in Billings MT...
# ...

# %%
valores_unicos_severity= df_filtrado['severity'].unique()
valores_unicos_severity
# Out:
# array(['Moderate', 'Severe', 'Minor', 'Extreme', 'Unknown'], dtype=object)

# %%
# Elimina los registros donde el campo 'severity' tiene el valor 'Unknown'
df_filtrado_sin_unknown = df_filtrado.loc[df_filtrado['urgency'] != 'Unknown']

# %%
df_filtrado_sin_unknown.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1497260 entries, 0 to 2267337
# Data columns (total 6 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   id           1497260 non-null  object
#  1   event        1497260 non-null  object
#  2   description  1497260 non-null  object
#  3   instruction  1497260 non-null  object
#  4   urgency      1497260 non-null  object
#  5   severity     1497260 non-null  object
# dtypes: object(6)
# memory usage: 80.0+ MB

# %%
df_filtrado_sin_unknown
# Out:
#                                id                      event  \
# 0        5ed3a4b2283336e2e7db3a1c  Special Weather Statement
# 1        5ed3a07c283336e2e7d2bfa4              Flood Warning
# 2        5ed39e54283336e2e7d22306             Flood Advisory
# 3        5ed39e11283336e2e7d15e23                Flood Watch
# 4        5ed3962c283336e2e7c1d935              Flood Warning
# ...                           ...                        ...
# 2267325  613a5aee434e34d5ee03f0e1  Special Weather Statement
# 2267326  613a5c5b434e34d5ee06813a  Special Weather Statement
# 2267327  613a5c5b434e34d5ee06813f          Flash Flood Watch
# 2267333  613a5d4d434e34d5ee06a9a9         Dense Fog Advisory
# 2267337  613a5dc6434e34d5ee06bd10  Special Weather Statement
#
#                                                description  \
# 0        At 630 AM MDT/530 AM PDT/, Doppler radar was t...
# 1        ...The National Weather Service in Billings MT...
# ...
